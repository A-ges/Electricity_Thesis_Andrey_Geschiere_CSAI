# %%
from run_model import run_model

df_agents, df_daily, load_profiles, df_pricing = run_model(
    agents_pct     = [90, 5, 5],      #90% habit-driven, 5% price, 5% social
    network_code   = "300c",          #300-agent network, variant c
    days           = 10,
    graphs         = [1, 2],          #print aggregate load plots for days 1 and 2
    median_plot    = True,
    random_state   = 90,
    epsilon_social = 0.5,
    epsilon_price  = 0.25, 
    epsilon_habit  = 1)
# Out:
# Loading network 300c from networks.json...
# ->  300 agents loaded.
#   Group split: 270 Habit-driven, 15 Price-responsive, 15 Social-influenced  (total: 300)
# Initialising agents...
#
# Running simulation: 10 days, 300 agents, seed 90
#   epsilon_habit=1  epsilon_price=0.25  epsilon_social=0.5
#
# Day 1 / 10 | peak: 285.27 kW | mean: 191.98 kW | PAR: 1.49 | flex: 0.00 | norm_flex: 0.00 | price_mean: 7.73
# Day 2 / 10 | peak: 299.52 kW | mean: 191.22 kW | PAR: 1.57 | flex: 552.79 | norm_flex: 1.84 | price_mean: 7.76
# Day 3 / 10 | peak: 285.05 kW | mean: 189.53 kW | PAR: 1.50 | flex: 545.68 | norm_flex: 1.82 | price_mean: 7.73
# Day 4 / 10 | peak: 305.94 kW | mean: 192.29 kW | PAR: 1.59 | flex: 538.98 | norm_flex: 1.80 | price_mean: 7.71
# Day 5 / 10 | peak: 299.64 kW | mean: 192.34 kW | PAR: 1.56 | flex: 529.33 | norm_flex: 1.76 | price_mean: 7.77
# Day 6 / 10 | peak: 296.50 kW | mean: 191.01 kW | PAR: 1.55 | flex: 522.11 | norm_flex: 1.74 | price_mean: 7.76
# ...
