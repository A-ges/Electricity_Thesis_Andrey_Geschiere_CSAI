# %%
from run_model import run_model

df_agents, df_daily, load_profiles = run_model(
    agents_pct   = [100, 0, 0],
    # 80% habit-driven, 10% price, 10% social
    network_code = "450a",          # 500-agent network, variant a
    days         = 3,
    graphs       = [1, 2],      # print aggregate load plots for days 1, 7, 30
    median_plot  = True,
    random_state = 42,
)
# Out:
# Loading network '450a' from networks.json...
#   450 agents loaded.
#   Group split: 450 Habit-driven, 0 Price-responsive, 0 Social-influenced  (total: 450)
# Initialising agents...
#
# Running simulation: 3 days, 450 agents, seed 42
#   epsilon_habit=1.8  epsilon_price=0.4  epsilon_social=0.4
#
# Day   1/3  |  peak:  446.82 kW  |  mean: 288.40 kW  |  PAR: 1.549  |  flex: 0.00  |  price_mean: 7.729
# Day   2/3  |  peak:  410.41 kW  |  mean: 288.10 kW  |  PAR: 1.425  |  flex: 2538.08  |  price_mean: 7.762
# Day   3/3  |  peak:  413.83 kW  |  mean: 286.74 kW  |  PAR: 1.443  |  flex: 2384.16  |  price_mean: 7.730
#
# Building output DataFrames...
# Simulation complete.
#   df_agent_daily : (1350, 15)  (agents x days = 450 x 3)
#   df_daily       : (3, 31)        (one row per day)
#   load_profiles  : (3, 96)   (days x 96 slots)

# %%
print(df_daily)
# Out:
#    day  peak_load_kw  mean_load_kw       par  load_variance   load_cv  \
# 0    0    500.769108    319.274995  1.568457    5833.510441  0.239221
# 1    1    452.950232    320.124025  1.414921    4633.623392  0.212639
# 2    2    487.038605    317.076743  1.536028    5660.950567  0.237290
#
#    load_gini  total_energy_kwh  n_rebound_peaks  mean_price  ...  \
# 0   0.134321       7662.599878                1    7.728917  ...
# 1   0.121887       7682.976602                1    7.752458  ...
# 2   0.135083       7609.841841                1    7.667583  ...
#
#    flex_price_responsive_mean  cost_norm_price_responsive_mean  \
# 0                         NaN                              NaN
# 1                         NaN                              NaN
# 2                         NaN                              NaN
#
#    discomfort_price_responsive_mean  cost_flex_ratio_price_responsive_mean  \
# 0                               NaN                                    NaN
# ...
